# %% [markdown]
# <a href="https://colab.research.google.com/github/abdu1azeez/Super-Resolution-using-GANs/blob/master/SRGAN_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mega.py
# Out:
# Collecting mega.py
#   Downloading https://files.pythonhosted.org/packages/f2/6b/e58a92f35e2fe0652f50380368f7b7bee0b9470c02f9f6d2b49eca3e8c9e/mega.py-1.0.6-py2.py3-none-any.whl
# Requirement already satisfied: requests>=0.10 in /usr/local/lib/python3.6/dist-packages (from mega.py) (2.21.0)
# Requirement already satisfied: pathlib==1.0.1 in /usr/local/lib/python3.6/dist-packages (from mega.py) (1.0.1)
# Collecting tenacity<6.0.0,>=5.1.5
#   Downloading https://files.pythonhosted.org/packages/45/67/67bb1db087678bc5c6f20766cf18914dfe37b0b9d4e4c5bb87408460b75f/tenacity-5.1.5-py2.py3-none-any.whl
# Collecting pycryptodome<4.0.0,>=3.9.6
#   Downloading https://files.pythonhosted.org/packages/54/e4/72132c31a4cedc58848615502c06cedcce1e1ff703b4c506a7171f005a75/pycryptodome-3.9.6-cp36-cp36m-manylinux1_x86_64.whl (13.7MB)
#      |████████████████████████████████| 13.7MB 239kB/s
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=0.10->mega.py) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=0.10->mega.py) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=0.10->mega.py) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=0.10->mega.py) (1.24.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from tenacity<6.0.0,>=5.1.5->mega.py) (1.12.0)
# Installing collected packages: tenacity, pycryptodome, mega.py
# Successfully installed mega.py-1.0.6 pycryptodome-3.9.6 tenacity-5.1.5

# %%
#@title Import Dependencies
import  os,shutil
import cv2
import numpy as np
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt
from keras.models import Input, Model
from keras.layers import BatchNormalization, LeakyReLU, Conv2D, Dense, \
                         Flatten, Add, PReLU, Conv2DTranspose, Lambda, UpSampling2D                    
from keras.optimizers import Adam
from keras.applications import VGG19
from keras.callbacks import ReduceLROnPlateau
import tensorflow as tf
 
from google.colab import drive
from mega import Mega

from pylab import rcParams
rcParams['figure.figsize'] = 7.5, 10
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
print("Do u have 4GB space in your Google drive?\n")

ans = input()

if ans.upper() == 'YES':
  print("Saving Dataset in G Drive")

  drive.mount('/content/drive')
  Path = '/content/drive/My Drive'

else:
  print("Saving Dataset in Colab Storage. The files will get deleted, if colab gets disconnected")
  Path = "/content/"
os.chdir(Path)
# Out:
# Do u have 4GB space in your Google drive?
#
#
# Saving Dataset in Colab Storage. The files will get deleted, if colab gets disconnected

# %%
#@title Download DIV2K Dataset
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# Out:
# --2020-02-15 05:53:32--  http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.162
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.162|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip [following]
# --2020-02-15 05:53:32--  https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.162|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3530603713 (3.3G) [application/zip]
# Saving to: ‘DIV2K_train_HR.zip’
#
# DIV2K_train_HR.zip  100%[===================>]   3.29G  51.3MB/s    in 76s
#
# 2020-02-15 05:54:47 (44.6 MB/s) - ‘DIV2K_train_HR.zip’ saved [3530603713/3530603713]

# %%
mega = Mega()

#login via anonymous user
m = mega.login()

# Don't cancel while downloading, Kindly wait for the download to finish
m.download_url("https://mega.nz/#!iVl1gTTZ!2Nps9jlXOkA45BSPMzxux6ylpberr_lQX_EHBMNMmoo")
# Out:
# PosixPath('srgan_weights_epoch_500.h5')

# %%
#@title Creating folder for the data and unziping the file

# !unzip DIV2K_train_HR.zip -d /content/
os.chdir('/content/DIV2K_train_HR')
# Out:
# Archive:  DIV2K_train_HR.zip
#    creating: /content/DIV2K_train_HR/
#   inflating: /content/DIV2K_train_HR/0103.png
#   inflating: /content/DIV2K_train_HR/0413.png
#   inflating: /content/DIV2K_train_HR/0031.png
#   inflating: /content/DIV2K_train_HR/0660.png
#   inflating: /content/DIV2K_train_HR/0126.png
#   inflating: /content/DIV2K_train_HR/0793.png
#   inflating: /content/DIV2K_train_HR/0764.png
#   inflating: /content/DIV2K_train_HR/0550.png
#   inflating: /content/DIV2K_train_HR/0437.png
#   inflating: /content/DIV2K_train_HR/0374.png
#   inflating: /content/DIV2K_train_HR/0755.png
#   inflating: /content/DIV2K_train_HR/0614.png
#   inflating: /content/DIV2K_train_HR/0646.png
#   inflating: /content/DIV2K_train_HR/0371.png
#   inflating: /content/DIV2K_train_HR/0312.png
#   inflating: /content/DIV2K_train_HR/0108.png
#   inflating: /content/DIV2K_train_HR/0556.png
#   inflating: /content/DIV2K_train_HR/0794.png
#   inflating: /content/DIV2K_train_HR/0722.png
#   inflating: /content/DIV2K_train_HR/0780.png
#   inflating: /content/DIV2K_train_HR/0555.png
#   inflating: /content/DIV2K_train_HR/0439.png
#   inflating: /content/DIV2K_train_HR/0396.png
#   inflating: /content/DIV2K_train_HR/0666.png
#   inflating: /content/DIV2K_train_HR/0254.png
#   inflating: /content/DIV2K_train_HR/0344.png
#   inflating: /content/DIV2K_train_HR/0062.png
#   inflating: /content/DIV2K_train_HR/0657.png
#   inflating: /content/DIV2K_train_HR/0117.png
#   inflating: /content/DIV2K_train_HR/0395.png
#   inflating: /content/DIV2K_train_HR/0015.png
#   inflating: /content/DIV2K_train_HR/0335.png
#   inflating: /content/DIV2K_train_HR/0578.png
#   inflating: /content/DIV2K_train_HR/0142.png
#   inflating: /content/DIV2K_train_HR/0719.png
#   inflating: /content/DIV2K_train_HR/0101.png
#   inflating: /content/DIV2K_train_HR/0579.png
#   inflating: /content/DIV2K_train_HR/0504.png
#   inflating: /content/DIV2K_train_HR/0576.png
#   inflating: /content/DIV2K_train_HR/0590.png
#   inflating: /content/DIV2K_train_HR/0158.png
#   inflating: /content/DIV2K_train_HR/0384.png
#   inflating: /content/DIV2K_train_HR/0795.png
#   inflating: /content/DIV2K_train_HR/0668.png
#   inflating: /content/DIV2K_train_HR/0144.png
#   inflating: /content/DIV2K_train_HR/0642.png
#   inflating: /content/DIV2K_train_HR/0427.png
#   inflating: /content/DIV2K_train_HR/0593.png
#   inflating: /content/DIV2K_train_HR/0080.png
#   inflating: /content/DIV2K_train_HR/0050.png
#   inflating: /content/DIV2K_train_HR/0617.png
#   inflating: /content/DIV2K_train_HR/0608.png
#   inflating: /content/DIV2K_train_HR/0118.png
#   inflating: /content/DIV2K_train_HR/0082.png
#   inflating: /content/DIV2K_train_HR/0788.png
#   inflating: /content/DIV2K_train_HR/0042.png
#   inflating: /content/DIV2K_train_HR/0333.png
#   inflating: /content/DIV2K_train_HR/0346.png
#   inflating: /content/DIV2K_train_HR/0705.png
#   inflating: /content/DIV2K_train_HR/0195.png
#   inflating: /content/DIV2K_train_HR/0671.png
#   inflating: /content/DIV2K_train_HR/0213.png
#   inflating: /content/DIV2K_train_HR/0692.png
#   inflating: /content/DIV2K_train_HR/0253.png
#   inflating: /content/DIV2K_train_HR/0191.png
#   inflating: /content/DIV2K_train_HR/0628.png
#   inflating: /content/DIV2K_train_HR/0354.png
#   inflating: /content/DIV2K_train_HR/0003.png
#   inflating: /content/DIV2K_train_HR/0393.png
#   inflating: /content/DIV2K_train_HR/0336.png
#   inflating: /content/DIV2K_train_HR/0674.png
#   inflating: /content/DIV2K_train_HR/0586.png
#   inflating: /content/DIV2K_train_HR/0074.png
#   inflating: /content/DIV2K_train_HR/0116.png
#   inflating: /content/DIV2K_train_HR/0270.png
#   inflating: /content/DIV2K_train_HR/0376.png
#   inflating: /content/DIV2K_train_HR/0650.png
#   inflating: /content/DIV2K_train_HR/0462.png
#   inflating: /content/DIV2K_train_HR/0046.png
#   inflating: /content/DIV2K_train_HR/0545.png
#   inflating: /content/DIV2K_train_HR/0347.png
#   inflating: /content/DIV2K_train_HR/0187.png
#   inflating: /content/DIV2K_train_HR/0713.png
#   inflating: /content/DIV2K_train_HR/0558.png
#   inflating: /content/DIV2K_train_HR/0319.png
#   inflating: /content/DIV2K_train_HR/0073.png
#   inflating: /content/DIV2K_train_HR/0033.png
#   inflating: /content/DIV2K_train_HR/0207.png
#   inflating: /content/DIV2K_train_HR/0290.png
#   inflating: /content/DIV2K_train_HR/0194.png
#   inflating: /content/DIV2K_train_HR/0246.png
#   inflating: /content/DIV2K_train_HR/0034.png
#   inflating: /content/DIV2K_train_HR/0621.png
#   inflating: /content/DIV2K_train_HR/0768.png
#   inflating: /content/DIV2K_train_HR/0366.png
#   inflating: /content/DIV2K_train_HR/0490.png
#   inflating: /content/DIV2K_train_HR/0471.png
#   inflating: /content/DIV2K_train_HR/0475.png
#   inflating: /content/DIV2K_train_HR/0152.png
#   inflating: /content/DIV2K_train_HR/0636.png
#   inflating: /content/DIV2K_train_HR/0338.png
#   inflating: /content/DIV2K_train_HR/0358.png
#   inflating: /content/DIV2K_train_HR/0523.png
#   inflating: /content/DIV2K_train_HR/0456.png
#   inflating: /content/DIV2K_train_HR/0470.png
#   inflating: /content/DIV2K_train_HR/0522.png
#   inflating: /content/DIV2K_train_HR/0426.png
#   inflating: /content/DIV2K_train_HR/0587.png
#   inflating: /content/DIV2K_train_HR/0465.png
#   inflating: /content/DIV2K_train_HR/0236.png
#   inflating: /content/DIV2K_train_HR/0192.png
#   inflating: /content/DIV2K_train_HR/0458.png
#   inflating: /content/DIV2K_train_HR/0438.png
#   inflating: /content/DIV2K_train_HR/0176.png
#   inflating: /content/DIV2K_train_HR/0016.png
#   inflating: /content/DIV2K_train_HR/0392.png
#   inflating: /content/DIV2K_train_HR/0054.png
#   inflating: /content/DIV2K_train_HR/0063.png
#   inflating: /content/DIV2K_train_HR/0537.png
#   inflating: /content/DIV2K_train_HR/0271.png
#   inflating: /content/DIV2K_train_HR/0409.png
#   inflating: /content/DIV2K_train_HR/0328.png
#   inflating: /content/DIV2K_train_HR/0582.png
#   inflating: /content/DIV2K_train_HR/0532.png
#   inflating: /content/DIV2K_train_HR/0706.png
#   inflating: /content/DIV2K_train_HR/0153.png
#   inflating: /content/DIV2K_train_HR/0401.png
#   inflating: /content/DIV2K_train_HR/0110.png
#   inflating: /content/DIV2K_train_HR/0316.png
#   inflating: /content/DIV2K_train_HR/0069.png
#   inflating: /content/DIV2K_train_HR/0209.png
#   inflating: /content/DIV2K_train_HR/0351.png
#   inflating: /content/DIV2K_train_HR/0433.png
#   inflating: /content/DIV2K_train_HR/0534.png
#   inflating: /content/DIV2K_train_HR/0525.png
#   inflating: /content/DIV2K_train_HR/0353.png
#   inflating: /content/DIV2K_train_HR/0018.png
#   inflating: /content/DIV2K_train_HR/0592.png
#   inflating: /content/DIV2K_train_HR/0041.png
#   inflating: /content/DIV2K_train_HR/0398.png
#   inflating: /content/DIV2K_train_HR/0355.png
#   inflating: /content/DIV2K_train_HR/0492.png
#   inflating: /content/DIV2K_train_HR/0258.png
#   inflating: /content/DIV2K_train_HR/0051.png
#   inflating: /content/DIV2K_train_HR/0339.png
#   inflating: /content/DIV2K_train_HR/0156.png
#   inflating: /content/DIV2K_train_HR/0174.png
#   inflating: /content/DIV2K_train_HR/0526.png
#   inflating: /content/DIV2K_train_HR/0168.png
#   inflating: /content/DIV2K_train_HR/0515.png
#   inflating: /content/DIV2K_train_HR/0289.png
#   inflating: /content/DIV2K_train_HR/0700.png
#   inflating: /content/DIV2K_train_HR/0711.png
#   inflating: /content/DIV2K_train_HR/0317.png
#   inflating: /content/DIV2K_train_HR/0310.png
#   inflating: /content/DIV2K_train_HR/0075.png
#   inflating: /content/DIV2K_train_HR/0533.png
#   inflating: /content/DIV2K_train_HR/0345.png
#   inflating: /content/DIV2K_train_HR/0238.png
#   inflating: /content/DIV2K_train_HR/0493.png
#   inflating: /content/DIV2K_train_HR/0019.png
#   inflating: /content/DIV2K_train_HR/0559.png
#   inflating: /content/DIV2K_train_HR/0268.png
#   inflating: /content/DIV2K_train_HR/0746.png
#   inflating: /content/DIV2K_train_HR/0648.png
#   inflating: /content/DIV2K_train_HR/0112.png
#   inflating: /content/DIV2K_train_HR/0639.png
#   inflating: /content/DIV2K_train_HR/0216.png
#   inflating: /content/DIV2K_train_HR/0170.png
#   inflating: /content/DIV2K_train_HR/0408.png
#   inflating: /content/DIV2K_train_HR/0461.png
#   inflating: /content/DIV2K_train_HR/0774.png
#   inflating: /content/DIV2K_train_HR/0308.png
#   inflating: /content/DIV2K_train_HR/0368.png
#   inflating: /content/DIV2K_train_HR/0341.png
#   inflating: /content/DIV2K_train_HR/0535.png
#   inflating: /content/DIV2K_train_HR/0585.png
#   inflating: /content/DIV2K_train_HR/0004.png
#   inflating: /content/DIV2K_train_HR/0496.png
#   inflating: /content/DIV2K_train_HR/0662.png
#   inflating: /content/DIV2K_train_HR/0173.png
#   inflating: /content/DIV2K_train_HR/0200.png
#   inflating: /content/DIV2K_train_HR/0752.png
#   inflating: /content/DIV2K_train_HR/0106.png
#   inflating: /content/DIV2K_train_HR/0520.png
#   inflating: /content/DIV2K_train_HR/0519.png
#   inflating: /content/DIV2K_train_HR/0157.png
#   inflating: /content/DIV2K_train_HR/0552.png
#   inflating: /content/DIV2K_train_HR/0735.png
#   inflating: /content/DIV2K_train_HR/0362.png
#   inflating: /content/DIV2K_train_HR/0410.png
#   inflating: /content/DIV2K_train_HR/0286.png
#   inflating: /content/DIV2K_train_HR/0627.png
#   inflating: /content/DIV2K_train_HR/0557.png
#   inflating: /content/DIV2K_train_HR/0266.png
#   inflating: /content/DIV2K_train_HR/0252.png
#   inflating: /content/DIV2K_train_HR/0206.png
#   inflating: /content/DIV2K_train_HR/0330.png
#   inflating: /content/DIV2K_train_HR/0088.png
#   inflating: /content/DIV2K_train_HR/0728.png
#   inflating: /content/DIV2K_train_HR/0641.png
#   inflating: /content/DIV2K_train_HR/0350.png
#   inflating: /content/DIV2K_train_HR/0083.png
#   inflating: /content/DIV2K_train_HR/0682.png
#   inflating: /content/DIV2K_train_HR/0549.png
#   inflating: /content/DIV2K_train_HR/0564.png
#   inflating: /content/DIV2K_train_HR/0476.png
#   inflating: /content/DIV2K_train_HR/0760.png
#   inflating: /content/DIV2K_train_HR/0629.png
#   inflating: /content/DIV2K_train_HR/0630.png
#   inflating: /content/DIV2K_train_HR/0032.png
#   inflating: /content/DIV2K_train_HR/0581.png
#   inflating: /content/DIV2K_train_HR/0056.png
#   inflating: /content/DIV2K_train_HR/0040.png
#   inflating: /content/DIV2K_train_HR/0169.png
#   inflating: /content/DIV2K_train_HR/0400.png
#   inflating: /content/DIV2K_train_HR/0172.png
#   inflating: /content/DIV2K_train_HR/0182.png
#   inflating: /content/DIV2K_train_HR/0269.png
#   inflating: /content/DIV2K_train_HR/0612.png
#   inflating: /content/DIV2K_train_HR/0649.png
#   inflating: /content/DIV2K_train_HR/0311.png
#   inflating: /content/DIV2K_train_HR/0723.png
#   inflating: /content/DIV2K_train_HR/0166.png
#   inflating: /content/DIV2K_train_HR/0155.png
#   inflating: /content/DIV2K_train_HR/0072.png
#   inflating: /content/DIV2K_train_HR/0149.png
#   inflating: /content/DIV2K_train_HR/0425.png
#   inflating: /content/DIV2K_train_HR/0715.png
#   inflating: /content/DIV2K_train_HR/0670.png
#   inflating: /content/DIV2K_train_HR/0460.png
#   inflating: /content/DIV2K_train_HR/0748.png
#   inflating: /content/DIV2K_train_HR/0147.png
#   inflating: /content/DIV2K_train_HR/0602.png
#   inflating: /content/DIV2K_train_HR/0610.png
#   inflating: /content/DIV2K_train_HR/0479.png
#   inflating: /content/DIV2K_train_HR/0603.png
#   inflating: /content/DIV2K_train_HR/0043.png
#   inflating: /content/DIV2K_train_HR/0190.png
#   inflating: /content/DIV2K_train_HR/0503.png
#   inflating: /content/DIV2K_train_HR/0055.png
#   inflating: /content/DIV2K_train_HR/0337.png
#   inflating: /content/DIV2K_train_HR/0453.png
#   inflating: /content/DIV2K_train_HR/0219.png
#   inflating: /content/DIV2K_train_HR/0548.png
#   inflating: /content/DIV2K_train_HR/0661.png
#   inflating: /content/DIV2K_train_HR/0718.png
#   inflating: /content/DIV2K_train_HR/0489.png
#   inflating: /content/DIV2K_train_HR/0775.png
#   inflating: /content/DIV2K_train_HR/0323.png
#   inflating: /content/DIV2K_train_HR/0664.png
#   inflating: /content/DIV2K_train_HR/0002.png
#   inflating: /content/DIV2K_train_HR/0127.png
#   inflating: /content/DIV2K_train_HR/0322.png
#   inflating: /content/DIV2K_train_HR/0640.png
#   inflating: /content/DIV2K_train_HR/0473.png
#   inflating: /content/DIV2K_train_HR/0730.png
#   inflating: /content/DIV2K_train_HR/0008.png
#   inflating: /content/DIV2K_train_HR/0486.png
#   inflating: /content/DIV2K_train_HR/0597.png
#   inflating: /content/DIV2K_train_HR/0064.png
#   inflating: /content/DIV2K_train_HR/0068.png
#   inflating: /content/DIV2K_train_HR/0510.png
#   inflating: /content/DIV2K_train_HR/0594.png
#   inflating: /content/DIV2K_train_HR/0685.png
#   inflating: /content/DIV2K_train_HR/0497.png
#   inflating: /content/DIV2K_train_HR/0637.png
#   inflating: /content/DIV2K_train_HR/0332.png
#   inflating: /content/DIV2K_train_HR/0208.png
#   inflating: /content/DIV2K_train_HR/0241.png
#   inflating: /content/DIV2K_train_HR/0201.png
#   inflating: /content/DIV2K_train_HR/0044.png
#   inflating: /content/DIV2K_train_HR/0141.png
#   inflating: /content/DIV2K_train_HR/0381.png
#   inflating: /content/DIV2K_train_HR/0412.png
#   inflating: /content/DIV2K_train_HR/0035.png
#   inflating: /content/DIV2K_train_HR/0049.png
#   inflating: /content/DIV2K_train_HR/0181.png
#   inflating: /content/DIV2K_train_HR/0340.png
#   inflating: /content/DIV2K_train_HR/0272.png
#   inflating: /content/DIV2K_train_HR/0279.png
#   inflating: /content/DIV2K_train_HR/0307.png
#   inflating: /content/DIV2K_train_HR/0733.png
#   inflating: /content/DIV2K_train_HR/0250.png
#   inflating: /content/DIV2K_train_HR/0739.png
#   inflating: /content/DIV2K_train_HR/0654.png
#   inflating: /content/DIV2K_train_HR/0343.png
#   inflating: /content/DIV2K_train_HR/0422.png
#   inflating: /content/DIV2K_train_HR/0297.png
#   inflating: /content/DIV2K_train_HR/0360.png
#   inflating: /content/DIV2K_train_HR/0099.png
#   inflating: /content/DIV2K_train_HR/0541.png
#   inflating: /content/DIV2K_train_HR/0616.png
#   inflating: /content/DIV2K_train_HR/0352.png
#   inflating: /content/DIV2K_train_HR/0092.png
#   inflating: /content/DIV2K_train_HR/0528.png
#   inflating: /content/DIV2K_train_HR/0483.png
#   inflating: /content/DIV2K_train_HR/0631.png
#   inflating: /content/DIV2K_train_HR/0134.png
#   inflating: /content/DIV2K_train_HR/0625.png
#   inflating: /content/DIV2K_train_HR/0530.png
#   inflating: /content/DIV2K_train_HR/0454.png
#   inflating: /content/DIV2K_train_HR/0624.png
#   inflating: /content/DIV2K_train_HR/0501.png
#   inflating: /content/DIV2K_train_HR/0038.png
#   inflating: /content/DIV2K_train_HR/0365.png
#   inflating: /content/DIV2K_train_HR/0789.png
#   inflating: /content/DIV2K_train_HR/0010.png
#   inflating: /content/DIV2K_train_HR/0543.png
#   inflating: /content/DIV2K_train_HR/0635.png
#   inflating: /content/DIV2K_train_HR/0418.png
#   inflating: /content/DIV2K_train_HR/0159.png
#   inflating: /content/DIV2K_train_HR/0689.png
#   inflating: /content/DIV2K_train_HR/0429.png
#   inflating: /content/DIV2K_train_HR/0276.png
#   inflating: /content/DIV2K_train_HR/0255.png
#   inflating: /content/DIV2K_train_HR/0293.png
#   inflating: /content/DIV2K_train_HR/0327.png
#   inflating: /content/DIV2K_train_HR/0488.png
#   inflating: /content/DIV2K_train_HR/0244.png
#   inflating: /content/DIV2K_train_HR/0721.png
#   inflating: /content/DIV2K_train_HR/0652.png
#   inflating: /content/DIV2K_train_HR/0779.png
#   inflating: /content/DIV2K_train_HR/0687.png
#   inflating: /content/DIV2K_train_HR/0326.png
#   inflating: /content/DIV2K_train_HR/0161.png
#   inflating: /content/DIV2K_train_HR/0498.png
#   inflating: /content/DIV2K_train_HR/0264.png
#   inflating: /content/DIV2K_train_HR/0136.png
#   inflating: /content/DIV2K_train_HR/0006.png
#   inflating: /content/DIV2K_train_HR/0741.png
#   inflating: /content/DIV2K_train_HR/0421.png
#   inflating: /content/DIV2K_train_HR/0229.png
#   inflating: /content/DIV2K_train_HR/0373.png
#   inflating: /content/DIV2K_train_HR/0703.png
#   inflating: /content/DIV2K_train_HR/0516.png
#   inflating: /content/DIV2K_train_HR/0234.png
#   inflating: /content/DIV2K_train_HR/0405.png
#   inflating: /content/DIV2K_train_HR/0763.png
#   inflating: /content/DIV2K_train_HR/0619.png
#   inflating: /content/DIV2K_train_HR/0138.png
#   inflating: /content/DIV2K_train_HR/0513.png
#   inflating: /content/DIV2K_train_HR/0432.png
#   inflating: /content/DIV2K_train_HR/0177.png
#   inflating: /content/DIV2K_train_HR/0017.png
#   inflating: /content/DIV2K_train_HR/0736.png
#   inflating: /content/DIV2K_train_HR/0459.png
#   inflating: /content/DIV2K_train_HR/0505.png
#   inflating: /content/DIV2K_train_HR/0397.png
#   inflating: /content/DIV2K_train_HR/0591.png
#   inflating: /content/DIV2K_train_HR/0196.png
#   inflating: /content/DIV2K_train_HR/0724.png
#   inflating: /content/DIV2K_train_HR/0740.png
#   inflating: /content/DIV2K_train_HR/0223.png
#   inflating: /content/DIV2K_train_HR/0442.png
#   inflating: /content/DIV2K_train_HR/0165.png
#   inflating: /content/DIV2K_train_HR/0302.png
#   inflating: /content/DIV2K_train_HR/0386.png
#   inflating: /content/DIV2K_train_HR/0601.png
#   inflating: /content/DIV2K_train_HR/0370.png
#   inflating: /content/DIV2K_train_HR/0647.png
#   inflating: /content/DIV2K_train_HR/0267.png
#   inflating: /content/DIV2K_train_HR/0380.png
#   inflating: /content/DIV2K_train_HR/0441.png
#   inflating: /content/DIV2K_train_HR/0037.png
#   inflating: /content/DIV2K_train_HR/0678.png
#   inflating: /content/DIV2K_train_HR/0304.png
#   inflating: /content/DIV2K_train_HR/0494.png
#   inflating: /content/DIV2K_train_HR/0028.png
#   inflating: /content/DIV2K_train_HR/0613.png
#   inflating: /content/DIV2K_train_HR/0257.png
#   inflating: /content/DIV2K_train_HR/0100.png
#   inflating: /content/DIV2K_train_HR/0097.png
#   inflating: /content/DIV2K_train_HR/0604.png
#   inflating: /content/DIV2K_train_HR/0023.png
#   inflating: /content/DIV2K_train_HR/0782.png
#   inflating: /content/DIV2K_train_HR/0446.png
#   inflating: /content/DIV2K_train_HR/0378.png
#   inflating: /content/DIV2K_train_HR/0411.png
#   inflating: /content/DIV2K_train_HR/0320.png
#   inflating: /content/DIV2K_train_HR/0390.png
#   inflating: /content/DIV2K_train_HR/0148.png
#   inflating: /content/DIV2K_train_HR/0577.png
#   inflating: /content/DIV2K_train_HR/0684.png
#   inflating: /content/DIV2K_train_HR/0595.png
#   inflating: /content/DIV2K_train_HR/0765.png
#   inflating: /content/DIV2K_train_HR/0203.png
#   inflating: /content/DIV2K_train_HR/0288.png
#   inflating: /content/DIV2K_train_HR/0058.png
#   inflating: /content/DIV2K_train_HR/0790.png
#   inflating: /content/DIV2K_train_HR/0605.png
#   inflating: /content/DIV2K_train_HR/0248.png
#   inflating: /content/DIV2K_train_HR/0467.png
#   inflating: /content/DIV2K_train_HR/0210.png
#   inflating: /content/DIV2K_train_HR/0517.png
#   inflating: /content/DIV2K_train_HR/0707.png
#   inflating: /content/DIV2K_train_HR/0566.png
#   inflating: /content/DIV2K_train_HR/0224.png
#   inflating: /content/DIV2K_train_HR/0114.png
#   inflating: /content/DIV2K_train_HR/0761.png
#   inflating: /content/DIV2K_train_HR/0468.png
#   inflating: /content/DIV2K_train_HR/0716.png
#   inflating: /content/DIV2K_train_HR/0420.png
#   inflating: /content/DIV2K_train_HR/0669.png
#   inflating: /content/DIV2K_train_HR/0375.png
#   inflating: /content/DIV2K_train_HR/0140.png
#   inflating: /content/DIV2K_train_HR/0792.png
#   inflating: /content/DIV2K_train_HR/0240.png
#   inflating: /content/DIV2K_train_HR/0546.png
#   inflating: /content/DIV2K_train_HR/0235.png
#   inflating: /content/DIV2K_train_HR/0077.png
#   inflating: /content/DIV2K_train_HR/0260.png
#   inflating: /content/DIV2K_train_HR/0212.png
#   inflating: /content/DIV2K_train_HR/0584.png
#   inflating: /content/DIV2K_train_HR/0633.png
#   inflating: /content/DIV2K_train_HR/0060.png
#   inflating: /content/DIV2K_train_HR/0164.png
#   inflating: /content/DIV2K_train_HR/0622.png
#   inflating: /content/DIV2K_train_HR/0105.png
#   inflating: /content/DIV2K_train_HR/0005.png
#   inflating: /content/DIV2K_train_HR/0679.png
#   inflating: /content/DIV2K_train_HR/0089.png
#   inflating: /content/DIV2K_train_HR/0466.png
#   inflating: /content/DIV2K_train_HR/0645.png
#   inflating: /content/DIV2K_train_HR/0301.png
#   inflating: /content/DIV2K_train_HR/0499.png
#   inflating: /content/DIV2K_train_HR/0020.png
#   inflating: /content/DIV2K_train_HR/0070.png
#   inflating: /content/DIV2K_train_HR/0404.png
#   inflating: /content/DIV2K_train_HR/0749.png
#   inflating: /content/DIV2K_train_HR/0770.png
#   inflating: /content/DIV2K_train_HR/0772.png
#   inflating: /content/DIV2K_train_HR/0450.png
#   inflating: /content/DIV2K_train_HR/0120.png
#   inflating: /content/DIV2K_train_HR/0653.png
#   inflating: /content/DIV2K_train_HR/0563.png
#   inflating: /content/DIV2K_train_HR/0171.png
#   inflating: /content/DIV2K_train_HR/0784.png
#   inflating: /content/DIV2K_train_HR/0688.png
#   inflating: /content/DIV2K_train_HR/0045.png
#   inflating: /content/DIV2K_train_HR/0066.png
#   inflating: /content/DIV2K_train_HR/0583.png
#   inflating: /content/DIV2K_train_HR/0632.png
#   inflating: /content/DIV2K_train_HR/0512.png
#   inflating: /content/DIV2K_train_HR/0767.png
#   inflating: /content/DIV2K_train_HR/0623.png
#   inflating: /content/DIV2K_train_HR/0406.png
#   inflating: /content/DIV2K_train_HR/0419.png
#   inflating: /content/DIV2K_train_HR/0273.png
#   inflating: /content/DIV2K_train_HR/0198.png
#   inflating: /content/DIV2K_train_HR/0750.png
#   inflating: /content/DIV2K_train_HR/0220.png
#   inflating: /content/DIV2K_train_HR/0482.png
#   inflating: /content/DIV2K_train_HR/0407.png
#   inflating: /content/DIV2K_train_HR/0704.png
#   inflating: /content/DIV2K_train_HR/0547.png
#   inflating: /content/DIV2K_train_HR/0589.png
#   inflating: /content/DIV2K_train_HR/0012.png
#   inflating: /content/DIV2K_train_HR/0150.png
#   inflating: /content/DIV2K_train_HR/0481.png
#   inflating: /content/DIV2K_train_HR/0357.png
#   inflating: /content/DIV2K_train_HR/0677.png
#   inflating: /content/DIV2K_train_HR/0315.png
#   inflating: /content/DIV2K_train_HR/0394.png
#   inflating: /content/DIV2K_train_HR/0160.png
#   inflating: /content/DIV2K_train_HR/0667.png
#   inflating: /content/DIV2K_train_HR/0568.png
#   inflating: /content/DIV2K_train_HR/0435.png
#   inflating: /content/DIV2K_train_HR/0606.png
#   inflating: /content/DIV2K_train_HR/0464.png
#   inflating: /content/DIV2K_train_HR/0364.png
#   inflating: /content/DIV2K_train_HR/0245.png
#   inflating: /content/DIV2K_train_HR/0508.png
#   inflating: /content/DIV2K_train_HR/0356.png
#   inflating: /content/DIV2K_train_HR/0135.png
#   inflating: /content/DIV2K_train_HR/0146.png
#   inflating: /content/DIV2K_train_HR/0574.png
#   inflating: /content/DIV2K_train_HR/0698.png
#   inflating: /content/DIV2K_train_HR/0222.png
#   inflating: /content/DIV2K_train_HR/0261.png
#   inflating: /content/DIV2K_train_HR/0444.png
#   inflating: /content/DIV2K_train_HR/0078.png
#   inflating: /content/DIV2K_train_HR/0123.png
#   inflating: /content/DIV2K_train_HR/0797.png
#   inflating: /content/DIV2K_train_HR/0274.png
#   inflating: /content/DIV2K_train_HR/0225.png
#   inflating: /content/DIV2K_train_HR/0180.png
#   inflating: /content/DIV2K_train_HR/0325.png
#   inflating: /content/DIV2K_train_HR/0372.png
#   inflating: /content/DIV2K_train_HR/0029.png
#   inflating: /content/DIV2K_train_HR/0318.png
#   inflating: /content/DIV2K_train_HR/0452.png
#   inflating: /content/DIV2K_train_HR/0115.png
#   inflating: /content/DIV2K_train_HR/0423.png
#   inflating: /content/DIV2K_train_HR/0615.png
#   inflating: /content/DIV2K_train_HR/0672.png
#   inflating: /content/DIV2K_train_HR/0231.png
#   inflating: /content/DIV2K_train_HR/0731.png
#   inflating: /content/DIV2K_train_HR/0389.png
#   inflating: /content/DIV2K_train_HR/0680.png
#   inflating: /content/DIV2K_train_HR/0329.png
#   inflating: /content/DIV2K_train_HR/0663.png
#   inflating: /content/DIV2K_train_HR/0659.png
#   inflating: /content/DIV2K_train_HR/0292.png
#   inflating: /content/DIV2K_train_HR/0284.png
#   inflating: /content/DIV2K_train_HR/0133.png
#   inflating: /content/DIV2K_train_HR/0727.png
#   inflating: /content/DIV2K_train_HR/0445.png
#   inflating: /content/DIV2K_train_HR/0139.png
#   inflating: /content/DIV2K_train_HR/0298.png
#   inflating: /content/DIV2K_train_HR/0282.png
#   inflating: /content/DIV2K_train_HR/0778.png
#   inflating: /content/DIV2K_train_HR/0565.png
#   inflating: /content/DIV2K_train_HR/0485.png
#   inflating: /content/DIV2K_train_HR/0495.png
#   inflating: /content/DIV2K_train_HR/0215.png
#   inflating: /content/DIV2K_train_HR/0694.png
#   inflating: /content/DIV2K_train_HR/0321.png
#   inflating: /content/DIV2K_train_HR/0094.png
#   inflating: /content/DIV2K_train_HR/0598.png
#   inflating: /content/DIV2K_train_HR/0430.png
#   inflating: /content/DIV2K_train_HR/0021.png
#   inflating: /content/DIV2K_train_HR/0036.png
#   inflating: /content/DIV2K_train_HR/0188.png
#   inflating: /content/DIV2K_train_HR/0334.png
#   inflating: /content/DIV2K_train_HR/0759.png
#   inflating: /content/DIV2K_train_HR/0217.png
#   inflating: /content/DIV2K_train_HR/0562.png
#   inflating: /content/DIV2K_train_HR/0124.png
#   inflating: /content/DIV2K_train_HR/0690.png
#   inflating: /content/DIV2K_train_HR/0385.png
#   inflating: /content/DIV2K_train_HR/0695.png
#   inflating: /content/DIV2K_train_HR/0708.png
#   inflating: /content/DIV2K_train_HR/0745.png
#   inflating: /content/DIV2K_train_HR/0007.png
#   inflating: /content/DIV2K_train_HR/0226.png
#   inflating: /content/DIV2K_train_HR/0256.png
#   inflating: /content/DIV2K_train_HR/0673.png
#   inflating: /content/DIV2K_train_HR/0451.png
#   inflating: /content/DIV2K_train_HR/0143.png
#   inflating: /content/DIV2K_train_HR/0403.png
#   inflating: /content/DIV2K_train_HR/0125.png
#   inflating: /content/DIV2K_train_HR/0132.png
#   inflating: /content/DIV2K_train_HR/0644.png
#   inflating: /content/DIV2K_train_HR/0796.png
#   inflating: /content/DIV2K_train_HR/0076.png
#   inflating: /content/DIV2K_train_HR/0211.png
#   inflating: /content/DIV2K_train_HR/0676.png
#   inflating: /content/DIV2K_train_HR/0121.png
#   inflating: /content/DIV2K_train_HR/0415.png
#   inflating: /content/DIV2K_train_HR/0536.png
#   inflating: /content/DIV2K_train_HR/0620.png
#   inflating: /content/DIV2K_train_HR/0331.png
#   inflating: /content/DIV2K_train_HR/0277.png
#   inflating: /content/DIV2K_train_HR/0611.png
#   inflating: /content/DIV2K_train_HR/0262.png
#   inflating: /content/DIV2K_train_HR/0305.png
#   inflating: /content/DIV2K_train_HR/0521.png
#   inflating: /content/DIV2K_train_HR/0221.png
#   inflating: /content/DIV2K_train_HR/0699.png
#   inflating: /content/DIV2K_train_HR/0743.png
#   inflating: /content/DIV2K_train_HR/0742.png
#   inflating: /content/DIV2K_train_HR/0111.png
#   inflating: /content/DIV2K_train_HR/0480.png
#   inflating: /content/DIV2K_train_HR/0720.png
#   inflating: /content/DIV2K_train_HR/0402.png
#   inflating: /content/DIV2K_train_HR/0561.png
#   inflating: /content/DIV2K_train_HR/0729.png
#   inflating: /content/DIV2K_train_HR/0296.png
#   inflating: /content/DIV2K_train_HR/0379.png
#   inflating: /content/DIV2K_train_HR/0014.png
#   inflating: /content/DIV2K_train_HR/0714.png
#   inflating: /content/DIV2K_train_HR/0754.png
#   inflating: /content/DIV2K_train_HR/0634.png
#   inflating: /content/DIV2K_train_HR/0725.png
#   inflating: /content/DIV2K_train_HR/0309.png
#   inflating: /content/DIV2K_train_HR/0197.png
#   inflating: /content/DIV2K_train_HR/0039.png
#   inflating: /content/DIV2K_train_HR/0696.png
#   inflating: /content/DIV2K_train_HR/0758.png
#   inflating: /content/DIV2K_train_HR/0599.png
#   inflating: /content/DIV2K_train_HR/0228.png
#   inflating: /content/DIV2K_train_HR/0712.png
#   inflating: /content/DIV2K_train_HR/0539.png
#   inflating: /content/DIV2K_train_HR/0781.png
#   inflating: /content/DIV2K_train_HR/0009.png
#   inflating: /content/DIV2K_train_HR/0145.png
#   inflating: /content/DIV2K_train_HR/0527.png
#   inflating: /content/DIV2K_train_HR/0263.png
#   inflating: /content/DIV2K_train_HR/0122.png
#   inflating: /content/DIV2K_train_HR/0506.png
#   inflating: /content/DIV2K_train_HR/0363.png
#   inflating: /content/DIV2K_train_HR/0249.png
#   inflating: /content/DIV2K_train_HR/0104.png
#   inflating: /content/DIV2K_train_HR/0800.png
#   inflating: /content/DIV2K_train_HR/0214.png
#   inflating: /content/DIV2K_train_HR/0658.png
#   inflating: /content/DIV2K_train_HR/0399.png
#   inflating: /content/DIV2K_train_HR/0572.png
#   inflating: /content/DIV2K_train_HR/0204.png
#   inflating: /content/DIV2K_train_HR/0651.png
#   inflating: /content/DIV2K_train_HR/0061.png
#   inflating: /content/DIV2K_train_HR/0026.png
#   inflating: /content/DIV2K_train_HR/0300.png
#   inflating: /content/DIV2K_train_HR/0162.png
#   inflating: /content/DIV2K_train_HR/0478.png
#   inflating: /content/DIV2K_train_HR/0022.png
#   inflating: /content/DIV2K_train_HR/0079.png
#   inflating: /content/DIV2K_train_HR/0285.png
#   inflating: /content/DIV2K_train_HR/0511.png
#   inflating: /content/DIV2K_train_HR/0025.png
#   inflating: /content/DIV2K_train_HR/0428.png
#   inflating: /content/DIV2K_train_HR/0436.png
#   inflating: /content/DIV2K_train_HR/0324.png
#   inflating: /content/DIV2K_train_HR/0447.png
#   inflating: /content/DIV2K_train_HR/0457.png
#   inflating: /content/DIV2K_train_HR/0424.png
#   inflating: /content/DIV2K_train_HR/0675.png
#   inflating: /content/DIV2K_train_HR/0469.png
#   inflating: /content/DIV2K_train_HR/0090.png
#   inflating: /content/DIV2K_train_HR/0179.png
#   inflating: /content/DIV2K_train_HR/0771.png
#   inflating: /content/DIV2K_train_HR/0431.png
#   inflating: /content/DIV2K_train_HR/0726.png
#   inflating: /content/DIV2K_train_HR/0609.png
#   inflating: /content/DIV2K_train_HR/0184.png
#   inflating: /content/DIV2K_train_HR/0747.png
#   inflating: /content/DIV2K_train_HR/0154.png
#   inflating: /content/DIV2K_train_HR/0391.png
#   inflating: /content/DIV2K_train_HR/0573.png
#   inflating: /content/DIV2K_train_HR/0071.png
#   inflating: /content/DIV2K_train_HR/0798.png
#   inflating: /content/DIV2K_train_HR/0693.png
#   inflating: /content/DIV2K_train_HR/0280.png
#   inflating: /content/DIV2K_train_HR/0414.png
#   inflating: /content/DIV2K_train_HR/0119.png
#   inflating: /content/DIV2K_train_HR/0757.png
#   inflating: /content/DIV2K_train_HR/0762.png
#   inflating: /content/DIV2K_train_HR/0734.png
#   inflating: /content/DIV2K_train_HR/0001.png
#   inflating: /content/DIV2K_train_HR/0265.png
#   inflating: /content/DIV2K_train_HR/0643.png
#   inflating: /content/DIV2K_train_HR/0567.png
#   inflating: /content/DIV2K_train_HR/0130.png
#   inflating: /content/DIV2K_train_HR/0580.png
#   inflating: /content/DIV2K_train_HR/0463.png
#   inflating: /content/DIV2K_train_HR/0218.png
#   inflating: /content/DIV2K_train_HR/0769.png
#   inflating: /content/DIV2K_train_HR/0507.png
#   inflating: /content/DIV2K_train_HR/0013.png
#   inflating: /content/DIV2K_train_HR/0233.png
#   inflating: /content/DIV2K_train_HR/0087.png
#   inflating: /content/DIV2K_train_HR/0093.png
#   inflating: /content/DIV2K_train_HR/0709.png
#   inflating: /content/DIV2K_train_HR/0027.png
#   inflating: /content/DIV2K_train_HR/0570.png
#   inflating: /content/DIV2K_train_HR/0342.png
#   inflating: /content/DIV2K_train_HR/0011.png
#   inflating: /content/DIV2K_train_HR/0287.png
#   inflating: /content/DIV2K_train_HR/0524.png
#   inflating: /content/DIV2K_train_HR/0791.png
#   inflating: /content/DIV2K_train_HR/0701.png
#   inflating: /content/DIV2K_train_HR/0783.png
#   inflating: /content/DIV2K_train_HR/0349.png
#   inflating: /content/DIV2K_train_HR/0766.png
#   inflating: /content/DIV2K_train_HR/0232.png
#   inflating: /content/DIV2K_train_HR/0314.png
#   inflating: /content/DIV2K_train_HR/0303.png
#   inflating: /content/DIV2K_train_HR/0697.png
#   inflating: /content/DIV2K_train_HR/0514.png
#   inflating: /content/DIV2K_train_HR/0377.png
#   inflating: /content/DIV2K_train_HR/0085.png
#   inflating: /content/DIV2K_train_HR/0113.png
#   inflating: /content/DIV2K_train_HR/0540.png
#   inflating: /content/DIV2K_train_HR/0383.png
#   inflating: /content/DIV2K_train_HR/0243.png
#   inflating: /content/DIV2K_train_HR/0086.png
#   inflating: /content/DIV2K_train_HR/0091.png
#   inflating: /content/DIV2K_train_HR/0151.png
#   inflating: /content/DIV2K_train_HR/0502.png
#   inflating: /content/DIV2K_train_HR/0294.png
#   inflating: /content/DIV2K_train_HR/0281.png
#   inflating: /content/DIV2K_train_HR/0656.png
#   inflating: /content/DIV2K_train_HR/0500.png
#   inflating: /content/DIV2K_train_HR/0237.png
#   inflating: /content/DIV2K_train_HR/0387.png
#   inflating: /content/DIV2K_train_HR/0178.png
#   inflating: /content/DIV2K_train_HR/0518.png
#   inflating: /content/DIV2K_train_HR/0239.png
#   inflating: /content/DIV2K_train_HR/0131.png
#   inflating: /content/DIV2K_train_HR/0655.png
#   inflating: /content/DIV2K_train_HR/0417.png
#   inflating: /content/DIV2K_train_HR/0776.png
#   inflating: /content/DIV2K_train_HR/0560.png
#   inflating: /content/DIV2K_train_HR/0737.png
#   inflating: /content/DIV2K_train_HR/0048.png
#   inflating: /content/DIV2K_train_HR/0128.png
#   inflating: /content/DIV2K_train_HR/0052.png
#   inflating: /content/DIV2K_train_HR/0137.png
#   inflating: /content/DIV2K_train_HR/0686.png
#   inflating: /content/DIV2K_train_HR/0053.png
#   inflating: /content/DIV2K_train_HR/0665.png
#   inflating: /content/DIV2K_train_HR/0691.png
#   inflating: /content/DIV2K_train_HR/0167.png
#   inflating: /content/DIV2K_train_HR/0313.png
#   inflating: /content/DIV2K_train_HR/0531.png
#   inflating: /content/DIV2K_train_HR/0569.png
#   inflating: /content/DIV2K_train_HR/0553.png
#   inflating: /content/DIV2K_train_HR/0047.png
#   inflating: /content/DIV2K_train_HR/0096.png
#   inflating: /content/DIV2K_train_HR/0756.png
#   inflating: /content/DIV2K_train_HR/0440.png
#   inflating: /content/DIV2K_train_HR/0199.png
#   inflating: /content/DIV2K_train_HR/0283.png
#   inflating: /content/DIV2K_train_HR/0247.png
#   inflating: /content/DIV2K_train_HR/0024.png
#   inflating: /content/DIV2K_train_HR/0193.png
#   inflating: /content/DIV2K_train_HR/0084.png
#   inflating: /content/DIV2K_train_HR/0102.png
#   inflating: /content/DIV2K_train_HR/0551.png
#   inflating: /content/DIV2K_train_HR/0575.png
#   inflating: /content/DIV2K_train_HR/0477.png
#   inflating: /content/DIV2K_train_HR/0098.png
#   inflating: /content/DIV2K_train_HR/0554.png
#   inflating: /content/DIV2K_train_HR/0189.png
#   inflating: /content/DIV2K_train_HR/0717.png
#   inflating: /content/DIV2K_train_HR/0732.png
#   inflating: /content/DIV2K_train_HR/0702.png
#   inflating: /content/DIV2K_train_HR/0183.png
#   inflating: /content/DIV2K_train_HR/0448.png
#   inflating: /content/DIV2K_train_HR/0455.png
#   inflating: /content/DIV2K_train_HR/0367.png
#   inflating: /content/DIV2K_train_HR/0251.png
#   inflating: /content/DIV2K_train_HR/0744.png
#   inflating: /content/DIV2K_train_HR/0785.png
#   inflating: /content/DIV2K_train_HR/0067.png
#   inflating: /content/DIV2K_train_HR/0163.png
#   inflating: /content/DIV2K_train_HR/0751.png
#   inflating: /content/DIV2K_train_HR/0299.png
#   inflating: /content/DIV2K_train_HR/0129.png
#   inflating: /content/DIV2K_train_HR/0291.png
#   inflating: /content/DIV2K_train_HR/0607.png
#   inflating: /content/DIV2K_train_HR/0242.png
#   inflating: /content/DIV2K_train_HR/0107.png
#   inflating: /content/DIV2K_train_HR/0175.png
#   inflating: /content/DIV2K_train_HR/0753.png
#   inflating: /content/DIV2K_train_HR/0278.png
#   inflating: /content/DIV2K_train_HR/0369.png
#   inflating: /content/DIV2K_train_HR/0571.png
#   inflating: /content/DIV2K_train_HR/0202.png
#   inflating: /content/DIV2K_train_HR/0030.png
#   inflating: /content/DIV2K_train_HR/0799.png
#   inflating: /content/DIV2K_train_HR/0474.png
#   inflating: /content/DIV2K_train_HR/0491.png
#   inflating: /content/DIV2K_train_HR/0638.png
#   inflating: /content/DIV2K_train_HR/0600.png
#   inflating: /content/DIV2K_train_HR/0596.png
#   inflating: /content/DIV2K_train_HR/0059.png
#   inflating: /content/DIV2K_train_HR/0186.png
#   inflating: /content/DIV2K_train_HR/0509.png
#   inflating: /content/DIV2K_train_HR/0529.png
#   inflating: /content/DIV2K_train_HR/0787.png
#   inflating: /content/DIV2K_train_HR/0382.png
#   inflating: /content/DIV2K_train_HR/0777.png
#   inflating: /content/DIV2K_train_HR/0109.png
#   inflating: /content/DIV2K_train_HR/0227.png
#   inflating: /content/DIV2K_train_HR/0388.png
#   inflating: /content/DIV2K_train_HR/0618.png
#   inflating: /content/DIV2K_train_HR/0681.png
#   inflating: /content/DIV2K_train_HR/0205.png
#   inflating: /content/DIV2K_train_HR/0472.png
#   inflating: /content/DIV2K_train_HR/0306.png
#   inflating: /content/DIV2K_train_HR/0361.png
#   inflating: /content/DIV2K_train_HR/0738.png
#   inflating: /content/DIV2K_train_HR/0230.png
#   inflating: /content/DIV2K_train_HR/0081.png
#   inflating: /content/DIV2K_train_HR/0095.png
#   inflating: /content/DIV2K_train_HR/0449.png
#   inflating: /content/DIV2K_train_HR/0626.png
#   inflating: /content/DIV2K_train_HR/0065.png
#   inflating: /content/DIV2K_train_HR/0443.png
#   inflating: /content/DIV2K_train_HR/0275.png
#   inflating: /content/DIV2K_train_HR/0542.png
#   inflating: /content/DIV2K_train_HR/0484.png
#   inflating: /content/DIV2K_train_HR/0359.png
#   inflating: /content/DIV2K_train_HR/0773.png
#   inflating: /content/DIV2K_train_HR/0434.png
#   inflating: /content/DIV2K_train_HR/0544.png
#   inflating: /content/DIV2K_train_HR/0416.png
#   inflating: /content/DIV2K_train_HR/0295.png
#   inflating: /content/DIV2K_train_HR/0538.png
#   inflating: /content/DIV2K_train_HR/0259.png
#   inflating: /content/DIV2K_train_HR/0348.png
#   inflating: /content/DIV2K_train_HR/0588.png
#   inflating: /content/DIV2K_train_HR/0710.png
#   inflating: /content/DIV2K_train_HR/0786.png
#   inflating: /content/DIV2K_train_HR/0185.png
#   inflating: /content/DIV2K_train_HR/0057.png
#   inflating: /content/DIV2K_train_HR/0487.png
#   inflating: /content/DIV2K_train_HR/0683.png

# %%
def crop_center(img,cropx,cropy):
    y,x,_ = img.shape
    startx = x//2-(cropx//2)
    starty = y//2-(cropy//2)    
    return img[starty:starty+cropy,startx:startx+cropx,:]

# %%
#@title Resizing the image
img_list, img_low_list = [], []
for i in os.listdir():
  if '.png' in i:
    img = cv2.imread(i)
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    img_crop = crop_center(img,256,256)
    img_list.append(img_crop)
    img_low_list.append(cv2.resize(img_crop,(64,64)))

high_reso_imgs = np.array(img_list)
low_reso_imgs = np.array(img_low_list)

# %%
img = cv2.imread(i)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img_crop = crop_center(img,256,256)

plt.imshow(cv2.resize(img_crop,(64,64)))

# %%
os.chdir('/content')

# %%
plt.figure(figsize = (15,15))
plt.subplot(1,2,1)
plt.imshow(high_reso_imgs[2])
plt.grid('off')
plt.axis('off')
plt.title('High Resolution')
plt.subplot(1,2,2)
plt.imshow(cv2.resize(low_reso_imgs[2],(256,256),
                      interpolation = cv2.INTER_CUBIC))
plt.grid('off')
plt.axis('off')
_=plt.title('low Resolution X4 (bicubic)')

# %%
#@title Creating the model
class SRGAN():
  # Implementation of SRGAN from paper:
  # https://arxiv.org/abs/1609.04802
    def __init__(self,lr_height = 64,lr_width = 64,channels = 3,
              upscale_factor = 4, generator_lr = 1e-4, discriminator_lr = 1e-4, gan_lr = 1e-4):
        self.height_low_reso = lr_height
        self.width_low_reso = lr_width

        if upscale_factor % 2 != 0:
            raise ValueError('Upscale factor is invalid, must be product of 2')

        self.upscale_factor = upscale_factor
        self.height_high_reso = self.height_low_reso * self.upscale_factor
        self.width_high_reso = self.width_low_reso * self.upscale_factor

        self.channels = channels
        self.shape_low_reso = (self.height_low_reso,self.width_low_reso,self.channels)
        self.shape_high_reso = (self.height_high_reso,self.width_high_reso,self.channels)

        self.samples = high_reso_imgs.shape[0]

        opti_generator = Adam(generator_lr,0.9)
        opti_discriminator = Adam(discriminator_lr,0.9)
        opti_gan = Adam(gan_lr,0.9) 

        self.vgg = self.bulid_vgg()

        self.discriminator = self.build_discriminator(opti_discriminator)
        self.discriminator.trainable = False
        self.generator = self.build_generator(opti_generator)
        self.srgan = self.build_srgan(opti_gan)

    def save_GAN_Model(self,epoch):
        self.srgan.save_weights('srgan_weights_epoch_%d.h5' % epoch)


    def plotLosses(self,dlosses,glosses,epo):
        fig, ax1 = plt.subplots(figsize = (10,12))
        color = 'tab:blue'
        ax1.plot(dlosses,color = color, label = 'Dis loss')
        ax1.set_xlabel('Epoch')
        ax1.set_ylabel('Dis loss', color = color)
        ax1.tick_params('y',color = color)
        color = 'tab:green'
        ax2 = ax1.twinx()
        ax2.plot(glosses, color = color, label = 'Gen loss')
        ax2.set_ylabel('Gen loss', color = color)
        ax2.tick_params('y', color = color)
        plt.title('Discriminator & Generator Losses')
        plt.savefig('Losses_%d.png' % epo)
        plt.show()

    def gen_pipeline(self, batch_size = 16):
        while(1):
            indx_high = np.random.randint(0,high_reso_imgs.shape[0]-1,batch_size)
            
            indx_low = np.random.randint(0,low_reso_imgs.shape[0]-1,batch_size)
            
            real = np.ones((batch_size,) + self.discriminator.output_shape[1:])
            
            fake = np.zeros((batch_size,) + self.discriminator.output_shape[1:])
            
            norm_hr = high_reso_imgs[indx_high]/127.5-1
            norm_lr = low_reso_imgs[indx_low]/127.5 -1
            yield(norm_hr,real,norm_lr,fake)
            
    def vgg_pipeline(self, batch_size = 16):
      while(1):
        indx = np.random.randint(0,high_reso_imgs.shape[0]-1,batch_size)
        real = np.ones((batch_size,) + self.discriminator.output_shape[1:])
        norm_hr = high_reso_imgs[indx]/127.5-1
        norm_lr = low_reso_imgs[indx]/127.5 -1
        yield(norm_hr,norm_lr,real)
            
      
    def bulid_vgg(self):
        vgg = VGG19(weights = "imagenet")
#         vgg.summary()
        vgg.outputs = [vgg.layers[9].output]
        img = Input(shape = self.shape_high_reso)
        img_features = vgg(img)
        vgg_model = Model(img, img_features)
#         for layer in vgg_model.layers:
#             layer.trainable = False
        vgg_model.compile(loss = 'mse', optimizer = Adam(0.0002,0.5),
                         metrics =['acc'])
        return vgg_model


    def residual_block(self,input_layer):
        x = Conv2D(filters = 64, kernel_size = 3, padding = 'same')(input_layer)
        x = BatchNormalization(momentum=0.8)(x)
        x = PReLU()(x)
        x = Conv2D(filters = 64, kernel_size = 3, padding = 'same')(x)
        x = BatchNormalization(momentum=0.8)(x)
        return Add()([input_layer,x])

    def disc_block(self,layer, n_filters, batch_norm = True):
        x = Conv2D(filters = n_filters, kernel_size = 3, padding = 'same')(layer)
        if batch_norm:
            x = BatchNormalization(momentum=0.8)(x)
        x = LeakyReLU(alpha=0.2)(x)
        x = Conv2D(filters = n_filters, kernel_size = 3,
                   strides=2, padding = 'same')(x)
        x = BatchNormalization(momentum=0.8)(x)
        x = LeakyReLU(alpha=0.2)(x)
        return x

    def Upsample_Block(self,x_in):
        x = Conv2D(filters = 256, kernel_size=3, padding='same')(x_in)
        x = self.SubpixelConv2D(2)(x)
        return PReLU()(x)
      
    def SubpixelConv2D(self,scale):
        return Lambda(lambda x: tf.depth_to_space(x, scale))
  
    def build_generator(self,opti_generator,n_blocks = 16):
        input_layer = Input(self.shape_low_reso)
        
        first_layer = Conv2D(filters = 64, kernel_size = 9,
                             padding = 'same')(input_layer)
        
        first_layer = PReLU()(first_layer)
        
        residual_blocks = self.residual_block(first_layer)
        
        for _ in range(n_blocks-1):
            residual_blocks = self.residual_block(residual_blocks)

        output_residual = Conv2D(filters = 64, kernel_size = 3,
                             padding = 'same')(residual_blocks)
        
        output_residual = BatchNormalization(momentum=0.8)(output_residual)
        
        output_residual = Add()([output_residual,first_layer])
               
        upsample_layer = self.Upsample_Block(output_residual)
        
        for _ in range(self.upscale_factor//2-1):
            upsample_layer =  self.Upsample_Block(upsample_layer)
            
        gen_output = Conv2D(filters = 3, kernel_size = 9,
                            padding = 'same', activation = 'tanh')(upsample_layer)

        gen_model = Model(inputs = input_layer, outputs = gen_output)
        gen_model.compile(loss = 'binary_crossentropy', optimizer = opti_generator)

        return gen_model

    def build_discriminator(self,opti_discriminator,n_blocks = 3, n_filters = 64):
        input_layer = Input(self.shape_high_reso)
        discriminator_blocks = self.disc_block(input_layer,n_filters,False)
        for i in range(n_blocks):
            discriminator_blocks = self.disc_block(discriminator_blocks, 
                                             n_filters = (i+1)*2*n_filters)
        
        #f_layer = GlobalAveragePooling2D()(discriminator_blocks)
        f_layer = Dense(units = 1024)(discriminator_blocks)
        f_layer = LeakyReLU(alpha=0.2)(f_layer)
        dis_output = Dense(units = 1, activation = 'sigmoid')(f_layer)
        disc_model = Model(inputs = input_layer, outputs = dis_output)
        disc_model.compile(loss = 'mse', optimizer = opti_discriminator,
                          metrics = ['accuracy'])

        return disc_model

    def build_srgan(self,optimizer):
        dis_input = Input(self.shape_high_reso)
        gen_input = Input(self.shape_low_reso)

        generated_high_reso = self.generator(gen_input)
        generated_features = self.vgg(generated_high_reso)
        generator_valid = self.discriminator(generated_high_reso)


        gan_model = Model(inputs = [gen_input, dis_input], 
                          outputs = [generator_valid, generated_features])
        
        for l in gan_model.layers[-1].layers[-1].layers:
          l.trainable=False
        
        gan_model.compile(loss = ['binary_crossentropy','mse'], loss_weights = [1e-2,1], optimizer = 'adam')
        gan_model.summary()
        
        return gan_model



    def train(self, epochs, save_interval = 100, batch_size = 16):
        pipeline = self.gen_pipeline(batch_size)
        vgg_pipeline = self.vgg_pipeline(batch_size)

        batch_count = self.samples // batch_size
        dlosses = []
        glosses = []
        for epo in range(1,epochs+1):
            print ('-'*15,'Epoch %d' % epo, '-'*15)
            for _ in tqdm(range(batch_count)):

                ##########################

                # Train the Discriminator

                ##########################

                # Generate Batch
                hr_imgs, real, lr_imgs, fake = next(pipeline)

                # Generate high resolution photos from low resolution photos
                generated_hr_imags = self.generator.predict(lr_imgs)

                # Train the discriminator 
                real_dis_loss = self.discriminator.train_on_batch(hr_imgs,real)
                fake_dis_loss = self.discriminator.train_on_batch(generated_hr_imags,fake)
                dis_loss = (0.5*np.add(real_dis_loss,fake_dis_loss))

                ##########################

                # Train the Generator

                ##########################

                #Generate Batch
                hr_imgs, lr_imgs, real = next(vgg_pipeline)

                # Extract ground truth using VGG model
                img_features = self.vgg.predict(hr_imgs)

                gan_loss = self.srgan.train_on_batch([lr_imgs,hr_imgs], [real, img_features])


            if epo % save_interval == 0:
              self.save_GAN_Model(epo)
              self.plotLosses(dlosses,glosses,epo)
            dlosses.append(gan_loss[1])
            glosses.append(gan_loss[0])
            print('\n',dlosses[-1],glosses[-1])

# %%
def plot_predict(low_reso_imgs,high_reso_imgs,srgan_model,n_imgs = 4):
    plt.figure(figsize = (12,12))
    plt.tight_layout()
    for i in range(0,n_imgs*3,3):
        idx = np.random.randint(0,low_reso_imgs.shape[0]-1)
        plt.subplot(n_imgs,3,i+1)
        plt.imshow(high_reso_imgs[idx])
        plt.grid('off')
        plt.axis('off')
        plt.title('Source')
        plt.subplot(n_imgs,3,i+2)
        plt.imshow(cv2.resize(low_reso_imgs[idx],(256,256),
                          interpolation = cv2.INTER_CUBIC))
        plt.grid('off')
        plt.axis('off')
        plt.title('X4 (bicubic)')
        
        img = srgan_model.generator.predict(np.expand_dims(low_reso_imgs[idx], axis = 0) / 127.5 - 1)
        img_unnorm = (img+1) * 127.5
        plt.subplot(n_imgs,3,i+3)
        plt.imshow(np.squeeze(img_unnorm, axis = 0).astype(np.uint8))
        plt.grid('off')
        plt.axis('off')
        plt.title('SRGAN')
        
    plt.savefig('predicted.png')

# %%
model_srgan = SRGAN()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels.h5
# 574717952/574710816 [==============================] - 16s 0us/step
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# model_3 (Model)                 (None, 256, 256, 3)  11252995    input_6[0][0]
# __________________________________________________________________________________________________
# model_2 (Model)                 (None, 16, 16, 1)    3759681     model_3[1][0]
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 64, 64, 256)  143667240   model_3[1][0]
# ==================================================================================================
# Total params: 158,679,916
# Trainable params: 11,248,771
# Non-trainable params: 147,431,145
# __________________________________________________________________________________________________

# %%
model_srgan.generator.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 64, 64, 64)   15616       input_4[0][0]
# __________________________________________________________________________________________________
# p_re_lu_1 (PReLU)               (None, 64, 64, 64)   262144      conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 64)   36928       p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 64)   256         conv2d_10[0][0]
# __________________________________________________________________________________________________
# p_re_lu_2 (PReLU)               (None, 64, 64, 64)   262144      batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 64)   36928       p_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, 64, 64)   256         conv2d_11[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 64)   0           p_re_lu_1[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 64)   36928       add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 64, 64, 64)   256         conv2d_12[0][0]
# __________________________________________________________________________________________________
# p_re_lu_3 (PReLU)               (None, 64, 64, 64)   262144      batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 64)   36928       p_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 64, 64, 64)   256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 64)   0           add_1[0][0]
#                                                                  batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 64)   36928       add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 64, 64, 64)   256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# p_re_lu_4 (PReLU)               (None, 64, 64, 64)   262144      batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 64)   36928       p_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 64, 64, 64)   256         conv2d_15[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 64)   0           add_2[0][0]
#                                                                  batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 64)   36928       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 64, 64, 64)   256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# p_re_lu_5 (PReLU)               (None, 64, 64, 64)   262144      batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 64)   36928       p_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 64, 64, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 64, 64, 64)   0           add_3[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 64)   36928       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 64, 64, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# p_re_lu_6 (PReLU)               (None, 64, 64, 64)   262144      batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 64)   36928       p_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 64, 64, 64)   256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 64, 64, 64)   0           add_4[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 64)   36928       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 64, 64, 64)   256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# p_re_lu_7 (PReLU)               (None, 64, 64, 64)   262144      batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 64)   36928       p_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 64, 64, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 64, 64, 64)   0           add_5[0][0]
#                                                                  batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 64)   36928       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 64, 64, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# p_re_lu_8 (PReLU)               (None, 64, 64, 64)   262144      batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 64)   36928       p_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 64, 64, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 64, 64, 64)   0           add_6[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 64)   36928       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 64, 64, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# p_re_lu_9 (PReLU)               (None, 64, 64, 64)   262144      batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 64, 64)   36928       p_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 64, 64, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 64, 64, 64)   0           add_7[0][0]
#                                                                  batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 64, 64)   36928       add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 64, 64, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# p_re_lu_10 (PReLU)              (None, 64, 64, 64)   262144      batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 64, 64)   36928       p_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 64, 64, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 64, 64)   0           add_8[0][0]
#                                                                  batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 64, 64)   36928       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 64, 64, 64)   256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# p_re_lu_11 (PReLU)              (None, 64, 64, 64)   262144      batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 64, 64)   36928       p_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 64, 64, 64)   256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 64, 64, 64)   0           add_9[0][0]
#                                                                  batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 64, 64)   36928       add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 64, 64, 64)   256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# p_re_lu_12 (PReLU)              (None, 64, 64, 64)   262144      batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 64, 64, 64)   36928       p_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 64, 64, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 64, 64, 64)   0           add_10[0][0]
#                                                                  batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 64, 64, 64)   36928       add_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 64, 64, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# p_re_lu_13 (PReLU)              (None, 64, 64, 64)   262144      batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 64, 64, 64)   36928       p_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 64, 64, 64)   256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 64, 64, 64)   0           add_11[0][0]
#                                                                  batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 64, 64, 64)   36928       add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 64, 64, 64)   256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# p_re_lu_14 (PReLU)              (None, 64, 64, 64)   262144      batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 64, 64)   36928       p_re_lu_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 64, 64, 64)   256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 64, 64, 64)   0           add_12[0][0]
#                                                                  batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 64, 64, 64)   36928       add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 64, 64, 64)   256         conv2d_36[0][0]
# __________________________________________________________________________________________________
# p_re_lu_15 (PReLU)              (None, 64, 64, 64)   262144      batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 64, 64, 64)   36928       p_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 64, 64, 64)   256         conv2d_37[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 64, 64, 64)   0           add_13[0][0]
#                                                                  batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 64, 64)   36928       add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 64, 64, 64)   256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# p_re_lu_16 (PReLU)              (None, 64, 64, 64)   262144      batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 64, 64, 64)   36928       p_re_lu_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 64, 64, 64)   256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 64, 64, 64)   0           add_14[0][0]
#                                                                  batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 64, 64, 64)   36928       add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 64, 64, 64)   256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# p_re_lu_17 (PReLU)              (None, 64, 64, 64)   262144      batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 64, 64, 64)   36928       p_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 64, 64, 64)   256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 64, 64, 64)   0           add_15[0][0]
#                                                                  batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 64, 64, 64)   36928       add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 64, 64, 64)   256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 64, 64, 64)   0           batch_normalization_40[0][0]
#                                                                  p_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 64, 64, 256)  147712      add_17[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 128, 128, 64) 0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# p_re_lu_18 (PReLU)              (None, 128, 128, 64) 1048576     lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 128, 128, 256 147712      p_re_lu_18[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 256, 256, 64) 0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# p_re_lu_19 (PReLU)              (None, 256, 256, 64) 4194304     lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 256, 256, 3)  15555       p_re_lu_19[0][0]
# ==================================================================================================
# Total params: 11,252,995
# Trainable params: 11,248,771
# Non-trainable params: 4,224
# __________________________________________________________________________________________________

# %%
model_srgan.discriminator.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 64)      1792
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 256, 256, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 64)      36928
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 128)     73856
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128, 128, 128)     512
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 128, 128, 128)     0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 128)       147584
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 64, 64, 128)       512
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 64, 256)       295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64, 64, 256)       1024
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 64, 64, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 32, 32, 256)       590080
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32, 32, 256)       1024
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 384)       885120
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 384)       1536
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 32, 32, 384)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 384)       1327488
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 16, 384)       1536
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 16, 16, 384)       0
# _________________________________________________________________
# dense_1 (Dense)              (None, 16, 16, 1024)      394240
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 16, 16, 1024)      0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16, 16, 1)         1025
# =================================================================
# Total params: 7,516,162
# Trainable params: 3,756,481
# Non-trainable params: 3,759,681
# _________________________________________________________________
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'

# %%
#@title Train the Model
# No. of epochs to run
Epochs = 1

# Load pretrained weights
model_srgan.srgan.load_weights(os.path.join(Path, 'srgan_weights_epoch_500.h5'))

# Train the model
model_srgan.train(Epochs)
# Out:
# --------------- Epoch 1 ---------------
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:493: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
#  11.23729 1.7448034

# %%
# @title Model Inference

plot_predict(low_reso_imgs,high_reso_imgs,model_srgan)

# %%
# @title Test on other images
# upload any image of resolution 256 x 256
# if there is a error then rerun the cell
os.chdir('/content/')
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-906a4b82-cac1-4388-926c-8d7c7be0bbe3" name="files[]" multiple disabled />
#      <output id="result-906a4b82-cac1-4388-926c-8d7c7be0bbe3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dog.jpg to dog.jpg

# %%
img = cv2.imread(list(uploaded.keys())[0])
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img_low = cv2.resize(img,(64,64), interpolation = cv2.INTER_CUBIC )

plt.figure(figsize = (15,15))
plt.subplot(1,3,1)
plt.imshow(img)
plt.grid('off')
plt.axis('off')
plt.title('High Resolution')

plt.subplot(1,3,2)
plt.imshow(cv2.resize(img_low,(256,256),
                      interpolation = cv2.INTER_CUBIC))
plt.grid('off')
plt.axis('off')
_=plt.title('low Resolution X4 (bicubic)')

plt.subplot(1,3,3)
img_low = np.expand_dims(img_low, axis = 0) / 127.5 - 1
img_high = model_srgan.generator.predict(img_low)
img_unnorm = (img_high+1) * 127.5

plt.imshow(np.squeeze(img_unnorm, axis = 0).astype(np.uint8))

plt.grid('off')
plt.axis('off')
_=plt.title('SRGANs')
